# %%
# 製作 orange() 及 gloria() 兩方法，分別爬取澄果旅遊和華泰旅遊網站內容，並轉出DataFrame表單
# 建立 mysql 連線，存取與讀出表單

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import time
import re

# %%
#取地今日時間

from datetime import datetime
from dateutil.relativedelta import relativedelta
n_days = datetime.now() + relativedelta(months=6)
print (n_days.strftime('%Y/%m/%d')) # %H:%M:%S'))
# Out:
# 2019/03/10

# %%
#建立資料庫引擎

from sqlalchemy import create_engine
import pymysql
engine = create_engine('mysql+pymysql://root:1qaz!QAZ@127.0.0.1:3306/tour?charset=utf8')

# %%
#設定資料庫連線

connect = pymysql.Connect(
#    host='localhost',
    host='127.0.0.1',
    port=3306,
    user='root',
    passwd='1qaz!QAZ',
    db='tour',
    charset='utf8'
)
    
cursor = connect.cursor()

# %%
#定義 getsqldata() 方法 
def getsqldata():
    data = pd.read_sql(sql=sql,con=connect)
    return data

# %%
#定義 orangeres 方法  取得orange旅行社網頁資料

def orangeres (p = 1):

    url = 'http://www.orangetour.com.tw/EW/Services/SearchListData.asp'
    page = p
    #headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'}
    payload={
        'displayType': 'G',
    #    'subCd': 
        'orderCd': '1',
        'pageALL': str(page),
        'pageGO': '1',
        'pagePGO': '1',
        'waitData': 'false',
        'waitPage': 'false',
    #    'mGrupCd': 
    #    'SrcCls': 
    #    'tabList':
    #    'regmCd': 
    #    'regsCd': 
        'beginDt': str(datetime.now().strftime('%Y/%m/%d')),
        'endDt': '9999/12/31',#str(n_days.strftime('%Y/%m/%d')),
    #    'portCd': 
    #    'tdays': 
    #    'bjt': 
    #    'carr': 
        'allowJoin': '1',
        'allowWait': '1'
    #    'ikeyword': 
    }
    rs = requests.session()
    res = rs.post(url,data = payload)

    res.encoding = 'utf-8'
    return res

# %%
# 定義 orangefp 方法  取得當日網站資料總數

def orangefp():
    url2 = 'http://www.orangetour.com.tw/EW/GO/GroupList.asp'
    
    res2 = requests.get(url2,'html.parser')
    res2.encoding = 'utf-8'
    soup = BeautifulSoup(res2.text,'html.parser')
    a = soup.find_all('ul',{'class':'pagination'})[0].find_all('li',{'class':'next'})[-1].find('a')['onclick']
    fp = re.search(r'\d+',a)
    return int(fp.group(0))

# %%
#getfp()

# %%
#定義 orange() 方法  用迴圈抓取所有網頁資料 並轉出DataFrame 表單

def orange():
    data2 = pd.DataFrame()
    p = 1
    total = 0
    fp = orangefp()
    print(fp)
    while True:
        res = orangeres(p)
        d = json.loads(res.text)
        d = d['All']

        for dd in d:
            df = pd.DataFrame([dd.values()])
            data2 = pd.concat([data2,df])
            
        total += len(d)
        print((p,total),end=",")
        

        if p == fp:        
            break
            
        p += 1
        time.sleep(2)
    data2.columns = (d[0].keys())
    data2['SignUpLink'] = data2['SignUpLink'].apply(lambda x:x['Name'])
    data2.reset_index(inplace = True,drop = True)
    return data2

# %%
data2 = orange()
data2.head()
# Out:
# 24
# (1, 20),(2, 40),(3, 60),(4, 80),(5, 100),(6, 120),(7, 140),(8, 160),(9, 180),(10, 200),(11, 220),(12, 240),(13, 260),(14, 280),(15, 300),(16, 320),(17, 340),(18, 360),(19, 380),(20, 400),(21, 420),(22, 440),(23, 460),(24, 465),
#          GrupCd      LeavDt WeekDay                         GrupSnm ItnRk3S  \
# 0  EW1080901BRA  2018/09/10       一    Hello! 長榮荷德比法 3遊船 OUTLET 10天
# 1  TYO180913ITA  2018/09/13       四                     東京蝦拼半自助漫遊五日
# 2  AK1080913KQA  2018/09/13       四               肯亞 野性呼喚10天 非洲王子系列
# 3  EE1080914BRA  2018/09/14       五  奧捷雙國、米其林、湖區、古堡、遊船、雙登塔10天(長榮直飛)
# 4  AS0680915ZZA  2018/09/15       六              小資奇幻極光 4+1晚 2次遇見極光
#
#    EstmYqt  DoneYqt  SaleYqt  DordQt  EstmTotqt  \
# 0       26        0        0       0         26
# 1       16        0       15       0         16
# 2       13        0       12       0         13
# 3       26        0       25       0         26
# 4        4        0        4       0          4
#
#                          ...                         SaleAm   AgtAm GrupLn  \
# 0                        ...                          69900   69900     10
# 1                        ...                          21999   21999      5
# 2                        ...                         159900  159900     10
# 3                        ...                          62900   62900     10
# 4                        ...                          17900   17900      6
#
#    SubCd SubCdAnm  SortSq                                         Url  \
# 0     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=EW1080901BRA
# 1     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=TYO180913ITA
# 2     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=AK1080913KQA
# 3     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=EE1080914BRA
# 4     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=AS0680915ZZA
#
#                                             ShareUrl  SrcCls  \
# 0  http://www.orangetour.com.tw/EW/GO/GroupDetail...       0
# 1  http://www.orangetour.com.tw/EW/GO/GroupDetail...       0
# 2  http://www.orangetour.com.tw/EW/GO/GroupDetail...       0
# 3  http://www.orangetour.com.tw/EW/GO/GroupDetail...       0
# 4  http://www.orangetour.com.tw/EW/GO/GroupDetail...       0
#
#                                              ImgUrl
# 0           /eweb_asiantour/images/default_demo.jpg
# 1  /eWeb_asiantour/IMGDB/000002/000003/00000380.JPG
# 2           /eweb_asiantour/images/default_demo.jpg
# 3           /eweb_asiantour/images/default_demo.jpg
# 4           /eweb_asiantour/images/default_demo.jpg
#
# [5 rows x 46 columns]

# %%
#檢查欄位屬性
data2.dtypes
# Out:
# GrupCd             object
# LeavDt             object
# WeekDay            object
# GrupSnm            object
# ItnRk3S            object
# EstmYqt             int64
# DoneYqt             int64
# SaleYqt             int64
# DordQt              int64
# EstmTotqt           int64
# PortNm             object
# FullSts            object
# RuleDr             object
# SaleCd              int64
# HotTp              object
# GordLk               bool
# OrderDl            object
# HtlOkFg              bool
# AdvFg                bool
# GuaranteeFg          bool
# PromoteFg            bool
# ApplyQt             int64
# DepositQt           int64
# NoDepositQt         int64
# RqstQt              int64
# SignUpLink         object
# IsShowGuarantee      bool
# IsShowPromote        bool
# IsShowHotTp          bool
# HotTpNm            object
# RecCnt              int64
# GoCnt               int64
# PgoCnt              int64
# RowId               int64
# SacctNo            object
# MgrupCd            object
# SaleAm              int64
# AgtAm               int64
# GrupLn              int64
# SubCd              object
# SubCdAnm           object
# SortSq              int64
# Url                object
# ShareUrl           object
# SrcCls              int64
# ImgUrl             object
# dtype: object

# %%
#檢查欄位內容
data2.loc[0]
# Out:
# GrupCd                                                  EW1080901BRA
# LeavDt                                                    2018/09/10
# WeekDay                                                            一
# GrupSnm                                 Hello! 長榮荷德比法 3遊船 OUTLET 10天
# ItnRk3S
# EstmYqt                                                           26
# DoneYqt                                                            0
# SaleYqt                                                            0
# DordQt                                                             0
# EstmTotqt                                                         26
# PortNm                                                      台北-桃園機場
# FullSts
# RuleDr
# SaleCd                                                             2
# HotTp                                                              3
# GordLk                                                         False
# OrderDl                                                   2018/09/10
# HtlOkFg                                                         True
# AdvFg                                                          False
# GuaranteeFg                                                    False
# PromoteFg                                                      False
# ApplyQt                                                          999
# DepositQt                                                        999
# NoDepositQt                                                        0
# RqstQt                                                           999
# SignUpLink                                                        候補
# IsShowGuarantee                                                False
# IsShowPromote                                                  False
# IsShowHotTp                                                     True
# HotTpNm                                                            滿
# RecCnt                                                           465
# GoCnt                                                            465
# PgoCnt                                                             0
# RowId                                                              1
# SacctNo
# MgrupCd                                                         EW21
# SaleAm                                                         69900
# AgtAm                                                          69900
# GrupLn                                                            10
# SubCd                                                             GO
# SubCdAnm                                                           團
# SortSq                                                             7
# Url                       /EW/GO/GroupDetail.asp?prodCd=EW1080901BRA
# ShareUrl           http://www.orangetour.com.tw/EW/GO/GroupDetail...
# SrcCls                                                             0
# ImgUrl                       /eweb_asiantour/images/default_demo.jpg
# Name: 0, dtype: object

# %%
#將資料依需求篩選欄位，並將欄位名稱改為旅遊咖網頁使用名稱，最後將結果存入mysql

date2 = data2[['GrupCd','LeavDt','GrupLn','WeekDay','PortNm']]
date2.rename(columns={'GrupCd':'group_code','LeavDt':'date','GrupLn':'days'},inplace = True)

date2.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      group_code        date  days WeekDay    PortNm
# 0  EW1080901BRA  2018/09/10    10       一  台北-桃園機場
# 1  TYO180913ITA  2018/09/13     5       四  台北-桃園機場
# 2  AK1080913KQA  2018/09/13    10       四  台北-桃園機場
# 3  EE1080914BRA  2018/09/14    10       五  台北-桃園機場
# 4  AS0680915ZZA  2018/09/15     6       六  台北-桃園機場

# %%
sql = (
"""    CREATE TABLE `tour`.`date2` (

  `group_code` VARCHAR(15) NOT NULL,
  `date` VARCHAR(10)  NULL,
  `days` INT NULL,
  `WeekDay` VARCHAR(2),
  `PortNm` VARCHAR(15) NULL,
  PRIMARY KEY (`group_code`),
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
date2.to_sql(name='date2',con=engine,  if_exists = 'append', index=False)
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xA5x\\xA5_\\xBC\\xD0...' for column 'VARIABLE_VALUE' at row 518")
#   result = self._query(query)

# %%
sale2 = data2[['GrupCd','SaleYqt','EstmTotqt','SaleAm']]
sale2.rename(columns={'GrupCd':'group_code','SaleYqt':'sell','EstmTotqt':'qty','SaleAm':'minprice'},inplace = True)

sale2.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      group_code  sell  qty  minprice
# 0  EW1080901BRA     0   26     69900
# 1  TYO180913ITA    15   16     21999
# 2  AK1080913KQA    12   13    159900
# 3  EE1080914BRA    25   26     62900
# 4  AS0680915ZZA     4    4     17900

# %%
sql = (
"""    CREATE TABLE `tour`.`sale2` (

  `group_code` VARCHAR(15) NOT NULL,
  `sell` INT NULL,
  `qty` INT NULL,
  `minprice` INT NULL,
  PRIMARY KEY (`group_code`),
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
sale2.to_sql(name='sale2',con=engine,  if_exists = 'append', index=False)

# %%
base2 = data2[['GrupSnm','GrupCd','SubCdAnm','SignUpLink','ImgUrl']]
base2['tour'] = 'orange'
base2.rename(columns={'GrupSnm':'title','GrupCd':'group_code','tour':'agency_code','ImgUrl':'pic'},inplace = True)

base2.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                             title    group_code SubCdAnm SignUpLink  \
# 0    Hello! 長榮荷德比法 3遊船 OUTLET 10天  EW1080901BRA        團         候補
# 1                     東京蝦拼半自助漫遊五日  TYO180913ITA        團         報名
# 2               肯亞 野性呼喚10天 非洲王子系列  AK1080913KQA        團         報名
# 3  奧捷雙國、米其林、湖區、古堡、遊船、雙登塔10天(長榮直飛)  EE1080914BRA        團         報名
# 4              小資奇幻極光 4+1晚 2次遇見極光  AS0680915ZZA        團         報名
#
#                                                 pic agency_code
# 0           /eweb_asiantour/images/default_demo.jpg      orange
# 1  /eWeb_asiantour/IMGDB/000002/000003/00000380.JPG      orange
# 2           /eweb_asiantour/images/default_demo.jpg      orange
# 3           /eweb_asiantour/images/default_demo.jpg      orange
# 4           /eweb_asiantour/images/default_demo.jpg      orange

# %%
sql = (
"""    CREATE  TABLE `tour`.`base2` (
`ID`          int         NOT NULL AUTO_INCREMENT,
  `title` VARCHAR(60)  NULL,
  `group_code` VARCHAR(15) NULL,
  `SubCdAnm` VARCHAR(2) NULL,
  `SignUpLink` VARCHAR(5) NULL,
  `pic` VARCHAR(100) NULL,
  `agency_code` VARCHAR(12) NULL,
  PRIMARY KEY (`ID`),
  UNIQUE INDEX `ID_UNIQUE` (`ID` ASC) VISIBLE,
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
base2.to_sql(name='base2',con=engine,  if_exists = 'append', index=False)

# %%
#############################分隔線  ##############################

# %%
def gloriares (p = 1):

    url = 'https://www.gloriatour.com.tw/EW/Services/SearchListData.asp'
    page = p
    #headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'}
    payload={
        'displayType': 'G',
    #    'subCd': 
        'orderCd': '1',
        'pageALL': str(page),
        'pageGO': '1',
        'pagePGO': '1',
        'waitData': 'false',
        'waitPage': 'false',
    #    'mGrupCd': 
    #    'SrcCls': 
    #    'tabList': 
    #    'regmCd': 
    #    'regsCd': 
        'beginDt': str(datetime.now().strftime('%Y/%m/%d')),
        'endDt': '9999/12/31',#str(n_days.strftime('%Y/%m/%d')),
    #    'portCd': 
    #    'tdays': 
    #    'bjt': 
    #    'carr': 
        'allowJoin': '1',
        'allowWait': '1'
    #    'ikeyword': 
    }
    rs = requests.session()
    res = rs.post(url,data = payload)

    res.encoding = 'big5'
    return res

# %%
def gloriafp():
    url2 = 'https://www.gloriatour.com.tw/EW/GO/GroupList.asp'
    
    res2 = requests.get(url2,'html.parser')
    res2.encoding = 'utf-8'
    soup = BeautifulSoup(res2.text,'html.parser')
    a = soup.find_all('ul',{'class':'pagination'})[0].find_all('li',{'class':'next'})[-1].find('a')['onclick']
    fp = re.search(r'\d+',a)
    return int(fp.group(0))

# %%
gloriafp()
# Out:
# 143

# %%
def gloria():
    data2 = pd.DataFrame()
    p = 1
    n=0
    total = 0
    fp = gloriafp()
    while True:
        res = gloriares(p)
        d = json.loads(res.text)
        d = d['All']
        
        for dd in d:
            df = pd.DataFrame([dd.values()])
            data2 = pd.concat([data2,df])
            
        total += len(d)
        print((p,total),end=",")
        
        if p == fp:
            break
            
        p += 1
        n += 1
        time.sleep(2)
    data2.columns = (d[0].keys())
    data2['SignUpLink'] = data2['SignUpLink'].apply(lambda x:x['Name'])
    data2.reset_index(inplace = True,drop = True)
    return data2

# %%
data1 = gloria()
data1.head()
# Out:
# (1, 20),(2, 40),(3, 60),(4, 80),(5, 100),(6, 120),(7, 140),(8, 160),(9, 180),(10, 200),(11, 220),(12, 240),(13, 260),(14, 280),(15, 300),(16, 320),(17, 340),(18, 360),(19, 380),(20, 400),(21, 420),(22, 440),(23, 460),(24, 480),(25, 500),(26, 520),(27, 540),(28, 560),(29, 580),(30, 600),(31, 620),(32, 640),(33, 660),(34, 680),(35, 700),(36, 720),(37, 740),(38, 760),(39, 780),(40, 800),(41, 820),(42, 840),(43, 860),(44, 880),(45, 900),(46, 920),(47, 940),(48, 960),(49, 980),(50, 1000),(51, 1020),(52, 1040),(53, 1060),(54, 1080),(55, 1100),(56, 1120),(57, 1140),(58, 1160),(59, 1180),(60, 1200),(61, 1220),(62, 1240),(63, 1260),(64, 1280),(65, 1300),(66, 1320),(67, 1340),(68, 1360),(69, 1380),(70, 1400),(71, 1420),(72, 1440),(73, 1460),(74, 1480),(75, 1500),(76, 1520),(77, 1540),(78, 1560),(79, 1580),(80, 1600),(81, 1620),(82, 1640),(83, 1660),(84, 1680),(85, 1700),(86, 1720),(87, 1740),(88, 1760),(89, 1780),(90, 1800),(91, 1820),(92, 1840),(93, 1860),(94, 1880),(95, 1900),(96, 1920),(97, 1940),(98, 1960),(99, 1980),(100, 2000),(101, 2020),(102, 2040),(103, 2060),(104, 2080),(105, 2100),(106, 2120),(107, 2140),(108, 2160),(109, 2180),(110, 2200),(111, 2220),(112, 2240),(113, 2260),(114, 2280),(115, 2300),(116, 2320),(117, 2340),(118, 2360),(119, 2380),(120, 2400),(121, 2420),(122, 2440),(123, 2460),(124, 2480),(125, 2500),(126, 2520),(127, 2540),(128, 2560),(129, 2580),(130, 2600),(131, 2620),(132, 2640),(133, 2660),(134, 2680),(135, 2700),(136, 2720),(137, 2740),(138, 2760),(139, 2780),(140, 2800),(141, 2820),(142, 2840),(143, 2853),
#          GrupCd      LeavDt WeekDay  \
# 0  SELB4BX8909A  2018/09/09       日
# 1  BKKHFCI8909A  2018/09/09       日
# 2  KWLB5CZ8909A  2018/09/09       日
# 3  KS205CI8909A  2018/09/09       日
# 4  WUXA6CI8909A  2018/09/09       日
#
#                                              GrupSnm ItnRk3S  EstmYqt  \
# 0     【精選釜慶】汗蒸幕體驗、佛國寺、泰迪熊博物館、天空步道、海洋博物館、太宗台、甘川洞文化村４日               17
# 1           【泰享樂】∼不走蛇園∼ 拉瑪雅納水上樂園、四面佛、鋼鐵人博物館超值五日遊(含稅)               18
# 2  【幸福一夏】桂林希爾頓、灕江精華遊印象劉三姐五天(無購物)※特別安排張藝謀印象劉三姐+商務V...               16
# 3      【馬新旺福】馬新雙國吉隆坡高塔自助餐馬六甲5D立體藝術館金沙娛樂城超值五日遊(新加坡一晚)               18
# 4  江南古運河畔小鎮漫時光 、三國影視城、入住超五星雲瀾灣白金溫泉酒店+自助餐 6日(無購物、無...               17
#
#    DoneYqt  SaleYqt  DordQt  EstmTotqt  \
# 0        0       19       0         20
# 1        0       17       0         18
# 2        0       15       0         16
# 3        0       17       0         18
# 4        0       16       0         17
#
#                          ...                         SaleAm  AgtAm GrupLn  \
# 0                        ...                          10800  10800      4
# 1                        ...                          15700  15700      5
# 2                        ...                          19900  19900      5
# 3                        ...                          20588  20588      5
# 4                        ...                          23900  23900      6
#
#    SubCd SubCdAnm  SortSq                                         Url  \
# 0     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=SELB4BX8909A
# 1     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=BKKHFCI8909A
# 2     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=KWLB5CZ8909A
# 3     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=KS205CI8909A
# 4     GO        團       7  /EW/GO/GroupDetail.asp?prodCd=WUXA6CI8909A
#
#                                             ShareUrl  SrcCls  \
# 0  https://www.gloriatour.com.tw/EW/GO/GroupDetai...       0
# 1  https://www.gloriatour.com.tw/EW/GO/GroupDetai...       0
# 2  https://www.gloriatour.com.tw/EW/GO/GroupDetai...       0
# 3  https://www.gloriatour.com.tw/EW/GO/GroupDetai...       0
# 4  https://www.gloriatour.com.tw/EW/GO/GroupDetai...       0
#
#                                               ImgUrl
# 0  /eWeb_gloriatour/IMGDB/000012/000013/000589/00...
# 1  /eWeb_gloriatour/IMGDB/000012/000014/001314/00...
# 2  /eWeb_gloriatour/IMGDB/000012/000090/000104/00...
# 3  /eWeb_gloriatour/IMGDB/000012/000014/000763/00...
# 4  /eWeb_gloriatour/IMGDB/000012/000090/000103/00...
#
# [5 rows x 46 columns]

# %%
data1.loc[0]
# Out:
# GrupCd                                                  SELB4BX8909A
# LeavDt                                                    2018/09/09
# WeekDay                                                            日
# GrupSnm               【精選釜慶】汗蒸幕體驗、佛國寺、泰迪熊博物館、天空步道、海洋博物館、太宗台、甘川洞文化村４日
# ItnRk3S
# EstmYqt                                                           17
# DoneYqt                                                            0
# SaleYqt                                                           19
# DordQt                                                             0
# EstmTotqt                                                         20
# PortNm                                                      台北-桃園機場
# FullSts
# RuleDr
# SaleCd                                                             1
# HotTp
# GordLk                                                         False
# OrderDl                                                   2018/09/09
# HtlOkFg                                                        False
# AdvFg                                                          False
# GuaranteeFg                                                    False
# PromoteFg                                                      False
# ApplyQt                                                          999
# DepositQt                                                        999
# NoDepositQt                                                        0
# RqstQt                                                           999
# SignUpLink                                                        報名
# IsShowGuarantee                                                False
# IsShowPromote                                                  False
# IsShowHotTp                                                    False
# HotTpNm
# RecCnt                                                          2853
# GoCnt                                                           2853
# PgoCnt                                                             0
# RowId                                                              1
# SacctNo
# MgrupCd                                                     SELB4-AB
# SaleAm                                                         10800
# AgtAm                                                          10800
# GrupLn                                                             4
# SubCd                                                             GO
# SubCdAnm                                                           團
# SortSq                                                             7
# Url                       /EW/GO/GroupDetail.asp?prodCd=SELB4BX8909A
# ShareUrl           https://www.gloriatour.com.tw/EW/GO/GroupDetai...
# SrcCls                                                             0
# ImgUrl             /eWeb_gloriatour/IMGDB/000012/000013/000589/00...
# Name: 0, dtype: object

# %%
date1 = data1[['GrupCd','LeavDt','GrupLn','WeekDay','PortNm']]
date1.rename(columns={'GrupCd':'group_code','LeavDt':'date','GrupLn':'days'},inplace = True)

date1.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      group_code        date  days WeekDay    PortNm
# 0  SELB4BX8909A  2018/09/09     4       日  台北-桃園機場
# 1  BKKHFCI8909A  2018/09/09     5       日  台北-桃園機場
# 2  KWLB5CZ8909A  2018/09/09     5       日  台北-桃園機場
# 3  KS205CI8909A  2018/09/09     5       日  台北-桃園機場
# 4  WUXA6CI8909A  2018/09/09     6       日  台北-桃園機場

# %%
sql = (
"""    CREATE TABLE `tour`.`date1` (

  `group_code` VARCHAR(15) NOT NULL,
  `date` VARCHAR(10)  NULL,
  `days` INT NULL,
  `WeekDay` VARCHAR(2),
  `PortNm` VARCHAR(15) NULL,
  PRIMARY KEY (`group_code`),
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
date1.to_sql(name='date1',con=engine,  if_exists = 'append', index=False)

# %%
sale1 = data1[['GrupCd','SaleYqt','EstmTotqt','SaleAm']]
sale1.rename(columns={'GrupCd':'group_code','SaleYqt':'sell','EstmTotqt':'qty','SaleAm':'minprice'},inplace = True)
sale1.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      group_code  sell  qty  minprice
# 0  SELB4BX8909A    19   20     10800
# 1  BKKHFCI8909A    17   18     15700
# 2  KWLB5CZ8909A    15   16     19900
# 3  KS205CI8909A    17   18     20588
# 4  WUXA6CI8909A    16   17     23900

# %%
sql = (
"""    CREATE TABLE `tour`.`sale1` (

  `group_code` VARCHAR(15) NOT NULL,
  `sell` INT NULL,
  `qty` INT NULL,
  `minprice` INT NULL,
  PRIMARY KEY (`group_code`),
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
sale1.to_sql(name='sale1',con=engine,  if_exists = 'append', index=False)

# %%
base1 = data1[['GrupSnm','GrupCd','SubCdAnm','SignUpLink','ImgUrl']]
base1['tour'] = 'gloria'
base1.rename(columns={'GrupSnm':'title','GrupCd':'group_code','tour':'agency_code','ImgUrl':'pic'},inplace = True)

base1.head()
# Out:
# e:\anacondax64\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# e:\anacondax64\envs\py36\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                                                title    group_code SubCdAnm  \
# 0     【精選釜慶】汗蒸幕體驗、佛國寺、泰迪熊博物館、天空步道、海洋博物館、太宗台、甘川洞文化村４日  SELB4BX8909A        團
# 1           【泰享樂】∼不走蛇園∼ 拉瑪雅納水上樂園、四面佛、鋼鐵人博物館超值五日遊(含稅)  BKKHFCI8909A        團
# 2  【幸福一夏】桂林希爾頓、灕江精華遊印象劉三姐五天(無購物)※特別安排張藝謀印象劉三姐+商務V...  KWLB5CZ8909A        團
# 3      【馬新旺福】馬新雙國吉隆坡高塔自助餐馬六甲5D立體藝術館金沙娛樂城超值五日遊(新加坡一晚)  KS205CI8909A        團
# 4  江南古運河畔小鎮漫時光 、三國影視城、入住超五星雲瀾灣白金溫泉酒店+自助餐 6日(無購物、無...  WUXA6CI8909A        團
#
#   SignUpLink                                                pic agency_code
# 0         報名  /eWeb_gloriatour/IMGDB/000012/000013/000589/00...      gloria
# 1         報名  /eWeb_gloriatour/IMGDB/000012/000014/001314/00...      gloria
# 2         報名  /eWeb_gloriatour/IMGDB/000012/000090/000104/00...      gloria
# 3         報名  /eWeb_gloriatour/IMGDB/000012/000014/000763/00...      gloria
# 4         報名  /eWeb_gloriatour/IMGDB/000012/000090/000103/00...      gloria

# %%
sql = (
"""    CREATE  TABLE `tour`.`base1` (
`ID`          int         NOT NULL AUTO_INCREMENT,
  `title` VARCHAR(60)  NULL,
  `group_code` VARCHAR(15) NULL,
  `SubCdAnm` VARCHAR(2) NULL,
  `SignUpLink` VARCHAR(5) NULL,
  `pic` VARCHAR(100) NULL,
  `agency_code` VARCHAR(12) NULL,
  PRIMARY KEY (`ID`),
  UNIQUE INDEX `ID_UNIQUE` (`ID` ASC) VISIBLE,
  UNIQUE INDEX `group_code_UNIQUE` (`group_code` ASC) VISIBLE);"""
)

cursor.execute(sql)
# Out:
# 0

# %%
base1.to_sql(name='base1',con=engine,  if_exists = 'append', index=False)

# %%
#########################  分隔線  ###################################

# %%
#由 mysql 讀取資料
sql  =  ('SELECT * FROM tour.base2;')
base2 =  getsqldata()
base2.head()
# Out:
#    ID                                 title    group_code SubCdAnm SignUpLink  \
# 0   1            品味法拉利 南北義 龐貝 藍洞 OUTLET 10天  EW1080909QRA        團         報名
# 1   2  浪漫愛琴海雙島：聖托里尼、米克諾斯、天空之城、諸神的故鄉、希臘10天之旅  ES1080909CAA        團        請電洽
# 2   3          Hello! 長榮荷德比法 3遊船 OUTLET 10天  EW1080901BRA        團         候補
# 3   4                             親子水陸雙樂園5日  ICN180912KEB        團         報名
# 4   5                       哈韓94狂～超人氣三大主題5日  ICN180912KEA        團         報名
#
#                                          pic agency_code
# 0  /eWeb_asiantour/IMGDB/000000/00005642.JPG      orange
# 1    /eweb_asiantour/images/default_demo.jpg      orange
# 2    /eweb_asiantour/images/default_demo.jpg      orange
# 3  /eWeb_asiantour/IMGDB/000126/00003008.JPG      orange
# 4    /eweb_asiantour/images/default_demo.jpg      orange

# %%
sql  =  ('SELECT * FROM tour.sale2;')
sale2 =  getsqldata()
sale2.head()
# Out:
#      group_code  sell  qty  minprice
# 0  0BKK181030IT    20   20     11900
# 1  0BKK181113IT    20   20     11900
# 2  0BKK181127IT    20   20     11900
# 3  0BKK181211IT    20   20     11900
# 4  0BKK181225IT    20   20     11900

# %%
sql  =  ('SELECT * FROM tour.date2;')
date2 =  getsqldata()
date2.head()
# Out:
#      group_code        date  days WeekDay    PortNm
# 0  0BKK181030IT  2018/10/30     5       二  台北-桃園機場
# 1  0BKK181113IT  2018/11/13     5       二  台北-桃園機場
# 2  0BKK181127IT  2018/11/27     5       二  台北-桃園機場
# 3  0BKK181211IT  2018/12/11     5       二  台北-桃園機場
# 4  0BKK181225IT  2018/12/25     5       二  台北-桃園機場

# %%
table2 = base2.merge(date2,on='group_code')
table2 = table2.merge(sale2,on='group_code')
table2.head()
# Out:
#    ID                                 title    group_code SubCdAnm SignUpLink  \
# 0   1            品味法拉利 南北義 龐貝 藍洞 OUTLET 10天  EW1080909QRA        團         報名
# 1   2  浪漫愛琴海雙島：聖托里尼、米克諾斯、天空之城、諸神的故鄉、希臘10天之旅  ES1080909CAA        團        請電洽
# 2   3          Hello! 長榮荷德比法 3遊船 OUTLET 10天  EW1080901BRA        團         候補
# 3   4                             親子水陸雙樂園5日  ICN180912KEB        團         報名
# 4   5                       哈韓94狂～超人氣三大主題5日  ICN180912KEA        團         報名
#
#                                          pic agency_code        date  days  \
# 0  /eWeb_asiantour/IMGDB/000000/00005642.JPG      orange  2018/09/09    10
# 1    /eweb_asiantour/images/default_demo.jpg      orange  2018/09/09    10
# 2    /eweb_asiantour/images/default_demo.jpg      orange  2018/09/10    10
# 3  /eWeb_asiantour/IMGDB/000126/00003008.JPG      orange  2018/09/12     5
# 4    /eweb_asiantour/images/default_demo.jpg      orange  2018/09/12     5
#
#   WeekDay    PortNm  sell  qty  minprice
# 0       日  台北-桃園機場     25   26     75900
# 1       日  台北-桃園機場      0   16     77900
# 2       一  台北-桃園機場      0   26     69900
# 3       三  台北-桃園機場     16   16     13000
# 4       三  台北-桃園機場     16   16     15000

# %%
date2.head()
# Out:
#      group_code        date  days WeekDay    PortNm
# 0  EW1080901BRA  2018/09/10    10       一  台北-桃園機場
# 1  TYO180913ITA  2018/09/13     5       四  台北-桃園機場
# 2  AK1080913KQA  2018/09/13    10       四  台北-桃園機場
# 3  EE1080914BRA  2018/09/14    10       五  台北-桃園機場
# 4  AS0680915ZZA  2018/09/15     6       六  台北-桃園機場

# %%
yy = ("""SELECT * FROM date2;""")
oldsql = pd.read_sql(sql=yy,con=connect)
oldsql.head()
# Out:
#      group_code        date  days WeekDay    PortNm
# 0  0BKK181030IT  2018/10/30     5       二  台北-桃園機場
# 1  0BKK181113IT  2018/11/13     5       二  台北-桃園機場
# 2  0BKK181127IT  2018/11/27     5       二  台北-桃園機場
# 3  0BKK181211IT  2018/12/11     5       二  台北-桃園機場
# 4  0BKK181225IT  2018/12/25     5       二  台北-桃園機場

# %%
list(oldsql['group_code'])
# Out:
# ['0BKK181030IT',
#  '0BKK181113IT',
#  '0BKK181127IT',
#  '0BKK181211IT',
#  '0BKK181225IT',
#  '0BKK190115IT',
#  '0HKG181015CI',
#  '0HKG181126CI',
#  '0HKG181210CI',
#  '0MFM181105IT',
#  '0MFM181119IT',
#  '0MFM181203IT',
#  '0MFM181217IT',
#  '0OKA181101MM',
#  '0OKA181129MM',
#  '0OKA181213MM',
#  '0OKA190105MM',
#  '0OKA190327MM',
#  'AE1081018RJA',
#  'AE1081028RJA',
#  'AE1081108RJA',
#  'AE1081113RJA',
#  'AE1081125RJA',
#  'AE1081129RJA',
#  'AE1081206RJA',
#  'AE1081216RJA',
#  'AE1090115RJA',
#  'AE1090120RJA',
#  'AE1090122RJA',
#  'AE1090129RJA',
#  'AE1090217RJA',
#  'AE1090224RJA',
#  'AE1090303JRA',
#  'AE1090310RJA',
#  'AE1090317RJA',
#  'AE1090324RJA',
#  'AE1181215RJA',
#  'AE1190112RJA',
#  'AE1190117RJA',
#  'AE1190119RJA',
#  'AE1190214RJA',
#  'AE1190216RJA',
#  'AE1190221RJA',
#  'AE1190228RJA',
#  'AE1190307RJA',
#  'AE1190314RJA',
#  'AE1190321RJA',
#  'AE1190328RJA',
#  'AK0880915KQA',
#  'AK0880922KQA',
#  'AK0881027KQA',
#  'AK0881103KQA',
#  'AK0881110KQA',
#  'AK0881117KQA',
#  'AK0881124KQA',
#  'AK1080913KQA',
#  'AK1080920KQA',
#  'AK1080927KQA',
#  'AN1080915QRA',
#  'AN1081006QRA',
#  'AS0680915ZZA',
#  'AS0680920ZZA',
#  'AS0680929ZZA',
#  'AS0681004ZZA',
#  'AS0681013ZZA',
#  'AS0681018ZZA',
#  'AS0681027ZZA',
#  'AS0681101ZZA',
#  'AS0681110ZZA',
#  'AS0681115ZZA',
#  'AS0681124ZZA',
#  'AS0681129ZZA',
#  'AS0681208ZZA',
#  'AS0681213ZZA',
#  'AS0681222ZZA',
#  'AS0681227ZZA',
#  'AS0690105ZZA',
#  'AS0690110ZZA',
#  'AS0690119ZZA',
#  'AS0690124ZZA',
#  'AS0690202ZZA',
#  'AS0690214ZZA',
#  'AS0690216ZZA',
#  'AS0690228ZZA',
#  'AS0690302ZZA',
#  'AS0690314ZZA',
#  'AS0690316ZZA',
#  'AS0690328ZZA',
#  'AS0690330ZZA',
#  'AS0690406ZZA',
#  'AS0780925ZZA',
#  'AS0781009ZZA',
#  'AS0781023ZZA',
#  'AS0781106ZZA',
#  'AS0781120ZZA',
#  'AS0781204ZZA',
#  'AS0781218ZZA',
#  'AS0790101ZZA',
#  'AS0790115ZZA',
#  'AS0790129ZZA',
#  'AS0790212ZZA',
#  'AS0790226ZZA',
#  'AS0790312ZZA',
#  'AS0790326ZZA',
#  'AS0881102BRA',
#  'AS0881206BRA',
#  'AS0890111BRA',
#  'AS0890202BRA',
#  'AS0890207BRA',
#  'AS0890227BRA',
#  'CTU991231FEK',
#  'DEL08180930A',
#  'DEL08181016A',
#  'DEL08181021A',
#  'DEL08181030A',
#  'DEL08181104A',
#  'DEL08181111A',
#  'DEL08181127A',
#  'DEL08181216A',
#  'DEL08181218A',
#  'EC1180915BRA',
#  'EE0881021BRA',
#  'EE0881026BRA',
#  'EE0881118BRA',
#  'EE0881125BRA',
#  'EE0881202BRA',
#  'EE0881209BRA',
#  'EE0881216BRA',
#  'EE0890105TRA',
#  'EE0890106BRA',
#  'EE0890113BRA',
#  'EE0890217BRA',
#  'EE0890228TRA',
#  'EE0890303BRA',
#  'EE0890314TRA',
#  'EE1080914BRA',
#  'EE1080917OSA',
#  'EE1080921BRA',
#  'EE1080928BRA',
#  'EE1081005BRA',
#  'EE1081005BRB',
#  'EE1081009OSA',
#  'EE1081012BRA',
#  'EE1081012BRB',
#  'EE1081012OSA',
#  'EE1081019BRA',
#  'EE1081019BRB',
#  'EE1081026BRA',
#  'EE1081026BRB',
#  'EE1081128BRA',
#  'EE1081201QRA',
#  'EE1081223BRA',
#  'EE1081223BRB',
#  'EE1081226BRA',
#  'EE1081226BRB',
#  'EE1081230BRA',
#  'EE1081230BRB',
#  'EE1090102BRA',
#  'EE1090102BRB',
#  'EE1090106BRA',
#  'EE1090109BRA',
#  'EE1090109BRB',
#  'EE1090113BRA',
#  'EE1090113BRB',
#  'EE1090120BRA',
#  'EE1090120BRB',
#  'EE1090123BRA',
#  'EE1090123BRB',
#  'EE1090210BRA',
#  'EE1090210BRB',
#  'EE1090210BRC',
#  'EE1090213BRA',
#  'EE1090213BRB',
#  'EE1090217BRA',
#  'EE1090217BRB',
#  'EE1090223QRA',
#  'EE1090224BRA',
#  'EE1090224BRB',
#  'EE1090227BRA',
#  'EE1090227BRB',
#  'EE1090306BRA',
#  'EE1090306BRB',
#  'EE1090309QRA',
#  'EE1090310BRA',
#  'EE1090313BRA',
#  'EE1090313BRB',
#  'EE1090314BRA',
#  'EE1090320BRB',
#  'EE1090320RA',
#  'EE1090323QRA',
#  'EE1090324BRA',
#  'EE1090327BRA',
#  'EE1090327BRB',
#  'EE1090330BRA',
#  'EE1090331BRA',
#  'EE1090331BRB',
#  'EE1181111HUA',
#  'EE1181125HUA',
#  'EE1181209HUA',
#  'EE1281007OSA',
#  'EH0781106QRA',
#  'EH0781120QRA',
#  'EH0781204QRA',
#  'EH0781211QRA',
#  'EH0790122QRA',
#  'EN0981018QRA',
#  'EN0981025QRA',
#  'EN0981108QRA',
#  'EN0981128QRA',
#  'EN0990114QRA',
#  'EN0990123QRA',
#  'ES0881120CAA',
#  'ES0881204CAA',
#  'ES0890101CAA',
#  'ES0890108CAA',
#  'ES0890305CAA',
#  'ES0890312CAA',
#  'ES1080909CAA',
#  'ES1081120CAA',
#  'ES1081225CAA',
#  'ES1090108CAA',
#  'ES1090205CAA',
#  'ES1090305CAA',
#  'ES1580925TKA',
#  'ES1581016TKA',
#  'ES1581030TKA',
#  'ES1581106TKA',
#  'ES1581120TKA',
#  'ES1581204TKA',
#  'EW0881104CAA',
#  'EW0881112LXA',
#  'EW0881126LXA',
#  'EW0881203LXA',
#  'EW0881212LXA',
#  'EW0890114LXA',
#  'EW0890121LXA',
#  'EW0890218LXA',
#  'EW0890225LXA',
#  'EW0890311LXA',
#  'EW0890318LXA',
#  'EW0890408LXA',
#  'EW0890415LXA',
#  'EW0981006CAA',
#  'EW0981105CIA',
#  'EW0981110LXA',
#  'EW0981112CIA',
#  'EW0981119CIA',
#  'EW0981124LXA',
#  'EW0981126CIA',
#  'EW0981203CIA',
#  'EW0981208LXA',
#  'EW0981210CIA',
#  'EW0981215LXA',
#  'EW0981217CIA',
#  'EW0990107CIA',
#  'EW0990112LXA',
#  'EW0990114CIA',
#  'EW0990119LXA',
#  'EW0990121CIA',
#  'EW0990128CIA',
#  'EW0990211CIA',
#  'EW0990216LXA',
#  'EW0990218CIA',
#  'EW0990223LXA',
#  'EW0990225CIA',
#  'EW0990304CIA',
#  'EW0990309LXA',
#  'EW0990311CIA',
#  'EW0990316LXA',
#  'EW0990318CIA',
#  'EW0990406LXA',
#  'EW0990420LXA',
#  'EW0990511LXA',
#  'EW0990518LXA',
#  'EW0990601LXA',
#  'EW0990608LXA',
#  'EW0990706LXA',
#  'EW0990720LXA',
#  'EW1080901BRA',
#  'EW1080909QRA',
#  'EW1080917BRA',
#  'EW1080923CAA',
#  'EW1080924BRA',
#  'EW1081001BRA',
#  'EW1081008BRA',
#  'EW1081014QRA',
#  'EW1081015BRA',
#  'EW1081022BRA',
#  'EW1081023CIA',
#  'EW1081028QRA',
#  'EW1081029BRA',
#  'EW1081105EYA',
#  'EW1081112EYA',
#  'EW1081112QRA',
#  'EW1081113CIA',
#  'EW1081116LXA',
#  'EW1081118CIA',
#  'EW1081119EYA',
#  'EW1081126EYA',
#  'EW1081127CIA',
#  'EW1081129CIA',
#  'EW1081130LXA',
#  'EW1081203EYA',
#  'EW1081204CIA',
#  'EW1081207LXA',
#  'EW1081209CIA',
#  'EW1081210EYA',
#  'EW1081211CIA',
#  'EW1081214LXA',
#  'EW1081217EYA',
#  'EW1090107EYA',
#  'EW1090108CIA',
#  'EW1090111LXA',
#  'EW1090114EYA',
#  'EW1090115CIA',
#  'EW1090118LXA',
#  'EW1090120CIA',
#  'EW1090121EYA',
#  'EW1090128EYA',
#  'EW1090211EYA',
#  'EW1090215LXA',
#  'EW1090218EYA',
#  'EW1090219CIA',
#  'EW1090222LXA',
#  'EW1090225EYA',
#  'EW1090226CIA',
#  'EW1090301LXA',
#  'EW1090304EYA',
#  'EW1090305CIA',
#  'EW1090311EYA',
#  'EW1090312CIA',
#  'EW1090315LXA',
#  'EW1090318EYA',
#  'EW1090329LXA',
#  'EW1090409CIA',
#  'EW1090412LXA',
#  'EW1090423CIA',
#  'EW1090426LXA',
#  'EW1090503LXA',
#  'EW1090503LXB',
#  'EW1090507CIA',
#  'EW1090510LXA',
#  'EW1090510LXB',
#  'EW1090517LXA',
#  'EW1090517LXB',
#  'EW1090521CIA',
#  'EW1090524LXA',
#  'EW1090524LXB',
#  'EW1090531LXA',
#  'EW1090531LXB',
#  'EW1090604CIA',
#  'EW1090607LXA',
#  'EW1090611CIA',
#  'EW1090614LXA',
#  'EW1090614LXB',
#  'EW1090618CIA',
#  'EW1090621LXA',
#  'EW1090621LXB',
#  'EW1090628LXA',
#  'EW1090628LXB',
#  'EW1090705LXA',
#  'EW1090705LXB',
#  'EW1090709CIA',
#  'EW1090712LXA',
#  'EW1090712LXB',
#  'EW1090716CIA',
#  'EW1090719LXA',
#  'EW1090719LXB',
#  'EW1090723CIA',
#  'EW1090726LXA',
#  'EW1090726LXB',
#  'EW1181106HUA',
#  'EW1181106HUB',
#  'EW1181120HUA',
#  'EW1181120HUB',
#  'EW1190115HUA',
#  'EW1190115HUB',
#  'EW1190305HUA',
#  'EW1190305HUB',
#  'EW1190312HUA',
#  'EW1190312HUB',
#  'EW1281106EKA',
#  'EW1281113EKA',
#  'EW1281120EKA',
#  'EW1281127EKA',
#  'EW1281204EKA',
#  'EW1281211EKA',
#  'EW1281218EKA',
#  'EW1281225EKA',
#  'EW1290108EKA',
#  'EW1290115EKA',
#  'EW1290122EKA',
#  'EW1290129EKA',
#  'EW1290212EKA',
#  'EW1290219EKA',
#  'EW1290226EKA',
#  'EW1290305EKA',
#  'EW1290312EKA',
#  'EW1290319EKA',
#  'EW1290326EKA',
#  'HAK180923HUA',
#  'HAK180923HUB',
#  'HAK180923HUC',
#  'HAK180930HUA',
#  'HAK180930HUB',
#  'HAK180930HUC',
#  'HAN991231B7K',
#  'HGH991231AEK',
#  'ICN180912KEA',
#  'ICN180912KEB',
#  'ICN180919KEA',
#  'ICN180919KEB',
#  'ICN180919KEE',
#  'ICN180922KEA',
#  'ICN180922KEB',
#  'ICN180926KEA',
#  'ICN180926KEB',
#  'LHW180919HUB',
#  'LHW181017HUB',
#  'LHW181024HUB',
#  'LHW181031HUB',
#  'ME1180925TKA',
#  'ME1181030TKA',
#  'ME1181101EKA',
#  'ME1181103EKA',
#  'ME1181107EKA',
#  'ME1181110EKA',
#  'ME1181115EKA',
#  'ME1181117EKA',
#  'ME1181122EKA',
#  'ME1181124EKA',
#  'ME1181129EKA',
#  'ME1181208EKA',
#  'ME1181213EKA',
#  'ME1181215TKA',
#  'ME1181222TKA',
#  'ME1190105TKA',
#  'ME1190112TKA',
#  'ME1190226TKA',
#  'ME1190302TKA',
#  'ME1190316TKA',
#  'MFM991231BRK',
#  'SS1080921TKA',
#  'SS1081109TKA',
#  'SS1081123TKA',
#  'SS1081207TKA',
#  'SS1081228TKA',
#  'SS1090111TKA',
#  'SS1090215TKA',
#  'SS1090301TKA',
#  'SS1090308TKA',
#  'SS1090315TKA',
#  'SS1090322TKA',
#  'TXN180919BRC',
#  'TXN180923BRB',
#  'TXN181007BRB',
#  'TXN181010BRC',
#  'TXN181014BRB',
#  'TXN181017BRC',
#  'TXN181021BRB',
#  'TXN181024BRC',
#  'TXN181028BRB',
#  'TXN181031BRC',
#  'TXN991231AEK',
#  'TYO180913ITA',
#  'TYO180920ITA',
#  'TYO180927ITA',
#  'TYO181004ITA',
#  'TYO181011ITA',
#  'TYO181018ITA',
#  'URC180928HUD']

# %%
date2['group_code']
# Out:
# 0      EW1080901BRA
# 1      TYO180913ITA
# 2      AK1080913KQA
# 3      EE1080914BRA
# 4      AS0680915ZZA
# 5      AN1080915QRA
# 6      EC1180915BRA
# 7      AK0880915KQA
# 8      EW1080917BRA
# 9      EE1080917OSA
# 10     ICN180919KEE
# 11     ICN180919KEB
# 12     ICN180919KEA
# 13     TYO180920ITA
# 14     AS0680920ZZA
# 15     AK1080920KQA
# 16     EE1080921BRA
# 17     SS1080921TKA
# 18     ICN180922KEB
# 19     ICN180922KEA
# 20     AK0880922KQA
# 21     HAK180923HUB
# 22     HAK180923HUA
# 23     HAK180923HUC
# 24     TXN180923BRB
# 25     EW1080923CAA
# 26     EW1080924BRA
# 27     AS0780925ZZA
# 28     ME1180925TKA
# 29     ES1580925TKA
#            ...
# 435    EW0990601LXA
# 436    EW1090604CIA
# 437    EW1090607LXA
# 438    EW0990608LXA
# 439    EW1090611CIA
# 440    EW1090614LXB
# 441    EW1090614LXA
# 442    EW1090618CIA
# 443    EW1090621LXB
# 444    EW1090621LXA
# 445    EW1090628LXB
# 446    EW1090628LXA
# 447    EW1090705LXB
# 448    EW1090705LXA
# 449    EW0990706LXA
# 450    EW1090709CIA
# 451    EW1090712LXB
# 452    EW1090712LXA
# 453    EW1090716CIA
# 454    EW1090719LXB
# 455    EW1090719LXA
# 456    EW0990720LXA
# 457    EW1090723CIA
# 458    EW1090726LXB
# 459    EW1090726LXA
# 460    MFM991231BRK
# 461    HGH991231AEK
# 462    HAN991231B7K
# 463    TXN991231AEK
# 464    CTU991231FEK
# Name: group_code, Length: 465, dtype: object

# %%
cursor = connect.cursor()
yy = ("""SELECT * FROM date2;""")
oldsql = pd.read_sql(sql=yy,con=connect)
#qaz = pd.read_excel('qaz.xlsx')
for newid in date2['group_code']:
    if newid not in list(oldsql['group_code']):
#        print(newid)
        insert = str((date2.loc[newid,'group_code'],date2.loc[newid,'date'],date2.loc[newid,'days'],date2.loc[newid,'WeekDay'],date2.loc[newid,'PortNm']))
        print(insert)
        sql = (
        """   INSERT INTO test.qaz
        values """+insert+"""
        ;"""
        )
        cursor.execute(sql)
        connect.commit()
for idx , ser in date2.iterrows():
    group_code = ser['group_code']
    date = ser['date']
    days = ser['days']
    WeekDay = ser['WeekDay']
    PortNm = ser['PortNm']

    
    sql = (
    """   UPDATE tour.date2
    SET date = """+'"'+date+'"'+""",days = """+str(days)+""",WeekDay = """+'"'+WeekDay+'"'+""",PortNm = """+'"'+PortNm+'"'+"""
    WHERE group_code = """+ '"'+group_code+'"'+"""
    ;"""
    )
    cursor.execute(sql)
    connect.commit()
cursor.close()

# %%
sale2.head()
# Out:
#      group_code  sell  qty  minprice
# 0  EW1080901BRA     0   26     69900
# 1  TYO180913ITA    15   16     21999
# 2  AK1080913KQA    12   13    159900
# 3  EE1080914BRA    25   26     62900
# 4  AS0680915ZZA     4    4     17900

# %%
cursor = connect.cursor()
yy = ("""SELECT * FROM sale2;""")
oldsql = pd.read_sql(sql=yy,con=connect)
#qaz = pd.read_excel('qaz.xlsx')
for newid in sale2['group_code']:
    if newid not in list(oldsql['group_code']):
#        print(newid)
        insert = str((sale2.loc[newid,'group_code'],sale2.loc[newid,'sell'],sale2.loc[newid,'qty'],sale2.loc[newid,'minprice']))
        print(insert)
        sql = (
        """   INSERT INTO test.qaz
        values """+insert+"""
        ;"""
        )
        cursor.execute(sql)
        connect.commit()
for idx , ser in sale2.iterrows():
    group_code = ser['group_code']
    sell = ser['sell']
    qty = ser['qty']
    minprice = ser['minprice']


    
    sql = (
    """   UPDATE tour.sale2
    SET sell = """+str(sell)+""",qty = """+str(qty)+""",minprice = """+str(minprice)+"""
    WHERE group_code = """+ '"'+group_code+'"'+"""
    ;"""
    )
    cursor.execute(sql)
    connect.commit()
cursor.close()

# %%
base2.head()
# Out:
#                             title    group_code SubCdAnm SignUpLink  \
# 0    Hello! 長榮荷德比法 3遊船 OUTLET 10天  EW1080901BRA        團         候補
# 1                     東京蝦拼半自助漫遊五日  TYO180913ITA        團         報名
# 2               肯亞 野性呼喚10天 非洲王子系列  AK1080913KQA        團         報名
# 3  奧捷雙國、米其林、湖區、古堡、遊船、雙登塔10天(長榮直飛)  EE1080914BRA        團         報名
# 4              小資奇幻極光 4+1晚 2次遇見極光  AS0680915ZZA        團         報名
#
#                                                 pic agency_code
# 0           /eweb_asiantour/images/default_demo.jpg      orange
# 1  /eWeb_asiantour/IMGDB/000002/000003/00000380.JPG      orange
# 2           /eweb_asiantour/images/default_demo.jpg      orange
# 3           /eweb_asiantour/images/default_demo.jpg      orange
# 4           /eweb_asiantour/images/default_demo.jpg      orange

# %%
cursor = connect.cursor()
yy = ("""SELECT * FROM base2;""")
oldsql = pd.read_sql(sql=yy,con=connect)
#qaz = pd.read_excel('qaz.xlsx')
for newid in base2['group_code']:
    if newid not in list(oldsql['group_code']):
#        print(newid)
        insert = str((base2.loc[newid,'title'],base2.loc[newid,'group_code'],base2.loc[newid,'SubCdAnm'],base2.loc[newid,'SignUpLink'],base2.loc[newid,'pic'],base2.loc[newid,'agency_code']))
        print(insert)
        sql = (
        """   INSERT INTO test.qaz
        values """+insert+"""
        ;"""
        )
        cursor.execute(sql)
        connect.commit()
for idx , ser in base2.iterrows():
    title = ser['title']
    group_code = ser['group_code']
    SubCdAnm = ser['SubCdAnm']
    SignUpLink = ser['SignUpLink']
    pic = ser['pic']
    agency_code = ser['agency_code']

    
    sql = (
    """   UPDATE tour.base2
    SET title = """+'"'+title+'"'+""",SubCdAnm = """+'"'+SubCdAnm+'"'+""",SignUpLink = """+'"'+SignUpLink+'"'+""",pic = """+'"'+pic+'"'+""",agency_code = """+'"'+agency_code+'"'+"""
    WHERE group_code = """+ '"'+group_code+'"'+"""
    ;"""
    )
    cursor.execute(sql)
    connect.commit()
cursor.close()

# %%
cursor.close()
